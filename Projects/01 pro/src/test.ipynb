# %%
a = 10

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
np.sqrt(a)
# Out:
# 3.1622776601683795

# %%
type(np.ceil(np.sqrt(a)))
# Out:
# numpy.float64

# %%
int(np.ceil(np.sqrt(a)))
# Out:
# 4

# %%
grid_size = 5

# %%
fig, axes = plt.subplots(grid_size, grid_size, figsize=(15, 15))

# %%
axes
# Out:
# array([[<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %%
np.random.choice([1, 5, 8, 4], size=2)
# Out:
# array([8, 1])

# %%
axes = axes.ravel()

# %%
axes
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >], dtype=object)

# %%
axes.type()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 axes.type()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'type'

# %%
type(axes)
# Out:
# numpy.ndarray

# %%
axes.shape
# Out:
# (25,)

# %%
axes[1]
# Out:
# <Axes: >

# %%
a = np.array([
    [1, 5], [2, 8], [3, 7]
])

# %%
a
# Out:
# array([[1, 5],
#        [2, 8],
#        [3, 7]])

# %%
a.shape
# Out:
# (3, 2)

# %%
a[1, 1]
# Out:
# 8

# %%
a.ravel()[1]
# Out:
# 5

# %%
a[2]
# Out:
# array([3, 7])

# %%
b = [8, 7, 9, 7]

# %%
enumerate(b)

# %%
import numpy as np
a = np.array([0] * 5)

# %%
np.array([0]).shape
# Out:
# (1,)

# %%
a
# Out:
# array([0, 0, 0, 0, 0])

# %%
a = a[[1, 4, 0, 2, 3]]

# %%
a
# Out:
# 0

# %%
a = range(10)

# %%
a
# Out:
# range(0, 10)

# %%
xs = [0, 2, 4, 5]

# %%
len(xs)
# Out:
# 4

# %%
range(0, len(xs))
# Out:
# range(0, 4)

# %%
list(range(0, len(xs)))
# Out:
# [0, 1, 2, 3]
